# %%
from warnings import filterwarnings
import warnings
warnings.filterwarnings('ignore')

# preprocessing and cleaning
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/minhhieu/Documents/AI_VN/data/clean/cleaned_reviews.csv')

# %%
df.isnull().sum()
# Out:
# Reviewer Name         0
# Country               0
# Review Count          0
# Review Date           0
# Rating                0
# Review Title          0
# Review Text           0
# Date of Experience    0
# full_review           0
# polarity_score        0
# Sentiment_Label       0
# dtype: int64

# %%
df.shape
# Out:
# (21055, 11)

# %%
df.head(1)
# Out:
#   Reviewer Name        Country Review Count               Review Date  \
# 0    Eugene ath  United States     1 review  2024-09-16T13:44:26.000Z
#
#                    Rating                                Review Title  \
# 0  Rated 1 out of 5 stars  A Store That Doesn't Want to Sell Anything
#
#                                          Review Text  Date of Experience  \
# 0  I registered on the website, tried to order a ...  September 16, 2024
#
#                                          full_review  polarity_score  \
# 0  store want sell anything registered website tr...          0.8898
#
#   Sentiment_Label
# 0             pos
